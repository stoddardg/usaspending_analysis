# %%
import pandas as pd
pd.options.display.max_columns=200
pd.options.display.max_rows=500
pd.options.display.max_colwidth=500

# from thefuzz import fuzz
# from thefuzz import process

from datetime import datetime

from glob import glob
import re

# %%
def normalize_program_names(_df, title_col = 'cfda_title'):

    df = _df.copy()
    df[title_col] = df[title_col].str.lower()
    df[title_col] = df[title_col].fillna('none')

    return df

# %%
def get_year(file_path):

    pattern = r'FY(\d{4})'

    # Search for the pattern in the string
    match = re.search(pattern, file_path)

    if match:
        year = match.group(1)
        return year
    else:
        return 1900

# %%
import re

all_data = []
for g in glob('usa_spending_contract_data/*/*',recursive=True):
    temp_data = pd.read_csv(g)
    temp_data['fiscal_year'] = get_year(g)
    all_data.append(temp_data)

raw_contracts = pd.concat(all_data)


# raw_contracts = pd.read_csv('usa_spending_contract_data/FY2019/All_Assistance_PrimeTransactions_2024-05-28_H10M16S23_1.csv')
# # raw_contracts = pd.read_csv('usa_spending_contract_data/FY2024/All_Assistance_PrimeTransactions_2024-05-28_H01M15S04_1.csv')
# Out:
# /opt/miniconda3/envs/standard_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (54) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
contracts = normalize_program_names(raw_contracts)

# %%
contracts['total_outlayed_amount_for_overall_award'] = contracts['total_outlayed_amount_for_overall_award'].fillna(0)

contracts['estimated_remaining_funds'] = contracts['total_obligated_amount'] - contracts['total_outlayed_amount_for_overall_award']

contracts['spent_percent'] = ((contracts['total_outlayed_amount_for_overall_award'] / contracts['total_obligated_amount'])*100).round(0)

contracts['remaining_funds_percent'] = ((contracts['estimated_remaining_funds'] / contracts['total_obligated_amount'])*100).round(0)

contracts['period_of_performance_current_end_date'] = pd.to_datetime(contracts['period_of_performance_current_end_date'])

contracts['period_of_performance_start_date'] = pd.to_datetime(contracts['period_of_performance_start_date'])
contracts['action_date'] = pd.to_datetime(contracts['action_date'])


contracts['grant_is_open'] = contracts['period_of_performance_current_end_date'] >= datetime(2024,9,1)


contracts['program_activities_funding_this_award'] = contracts['program_activities_funding_this_award'].fillna('missing')

# %% [markdown]
# # Code program names

# %%
program_map = {
    'comunity violence intervention and prevention intitiative':
        ['0153: COMMUNITY-BASED VIOLENCE PREVENTION INITIATIVES',
        #'public safety partnership and community policing grants',
        'community-based violence prevention program'],
    'victims of crime act (voca)':['0001: CRIME VICTIMS GRANTS AND ASSISTANCE','0006: TRIBAL VICTIMS ASSISTANCE GRANTS'],
    'center for culturally responsive victim services':[],
    'byrne memorial justice assistance grant':['0007: JUSTICE ASSISTANCE GRANTS','edward byrne memorial justice assistance grant program'],
    'byrne criminal justice innovation':['0081: COMMUNITY BASED CRIME REDUCTION PROGRAM (BYRNE CRIMINAL JUSTICE INNOVATION)'],
    'strategies to support children exposed to violence':['0024: CHILDREN EXPOSED TO VIOLENCE','children exposed to violence'],
    'project safe neighborhood':['0043: PROJECT SAFE NEIGHBORHOODS','project safe neighborhoods'],
    'youth violence and reductions':[],
    'school violence prevention program':['0143: STOP SCHOOL VIOLENCE ACT'],
    'second chance act community based re-entry program':['0050: SECOND CHANCE ACT/OFFENDER REENTRY'],
    'community policing development micro-grants':['0001: PUBLIC SAFETY AND COMMUNITY POLICING GRANTS'],
    'smart policing':['0021: STRATEGIES FOR POLICING INNOVATION'],
    'cops hiring program':['0009: COPS HIRING PROGRAM']
}

# %%
def match_grant_program_to_map(x):

    if x is None:
        return 'no match'

    program_matches = []
    for program_name, program_list in program_map.items():

        for program_code in program_list:
            if x.find(program_code) != -1:
                program_matches.append(program_name)
    
    # if len(program_matches) > 1:
    #     print(f"MULTIPLE MATCHES FOR {x}")
        
    
    if len(program_matches) == 0:
        return "no match"

    return program_matches[0]

# %%
contracts["program_match__funding_code"] = contracts[
    "program_activities_funding_this_award"
].apply(match_grant_program_to_map)

contracts["program_match__title"] = contracts["cfda_title"].apply(
    match_grant_program_to_map
)
contracts["program_match"] = contracts["program_match__funding_code"].where(
    contracts["program_match__funding_code"] != "no match",
    contracts["program_match__title"],
)

# %%
contracts.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48276 entries, 0 to 8810
# Data columns (total 120 columns):
# assistance_transaction_unique_key                                 object
# assistance_award_unique_key                                       object
# award_id_fain                                                     object
# modification_number                                               object
# award_id_uri                                                      object
# sai_number                                                        object
# federal_action_obligation                                         float64
# total_obligated_amount                                            float64
# total_outlayed_amount_for_overall_award                           float64
# indirect_cost_federal_share_amount                                float64
# non_federal_funding_amount                                        float64
# total_non_federal_funding_amount                                  float64
# face_value_of_loan                                                float64
# original_loan_subsidy_cost                                        float64
# total_face_value_of_loan                                          float64
# total_loan_subsidy_cost                                           float64
# generated_pragmatic_obligations                                   float64
# disaster_emergency_fund_codes_for_overall_award                   object
# outlayed_amount_from_COVID-19_supplementals_for_overall_award     float64
# obligated_amount_from_COVID-19_supplementals_for_overall_award    float64
# outlayed_amount_from_IIJA_supplemental_for_overall_award          float64
# obligated_amount_from_IIJA_supplemental_for_overall_award         float64
# action_date                                                       datetime64[ns]
# action_date_fiscal_year                                           int64
# period_of_performance_start_date                                  datetime64[ns]
# period_of_performance_current_end_date                            datetime64[ns]
# awarding_agency_code                                              int64
# awarding_agency_name                                              object
# awarding_sub_agency_code                                          int64
# awarding_sub_agency_name                                          object
# awarding_office_code                                              object
# awarding_office_name                                              object
# funding_agency_code                                               float64
# funding_agency_name                                               object
# funding_sub_agency_code                                           float64
# funding_sub_agency_name                                           object
# funding_office_code                                               object
# funding_office_name                                               object
# treasury_accounts_funding_this_award                              object
# federal_accounts_funding_this_award                               object
# object_classes_funding_this_award                                 object
# program_activities_funding_this_award                             object
# recipient_uei                                                     object
# recipient_duns                                                    float64
# recipient_name                                                    object
# recipient_name_raw                                                object
# recipient_parent_uei                                              object
# recipient_parent_duns                                             float64
# recipient_parent_name                                             object
# recipient_parent_name_raw                                         object
# recipient_country_code                                            object
# recipient_country_name                                            object
# recipient_address_line_1                                          object
# recipient_address_line_2                                          object
# recipient_city_code                                               object
# recipient_city_name                                               object
# prime_award_transaction_recipient_county_fips_code                int64
# recipient_county_name                                             object
# prime_award_transaction_recipient_state_fips_code                 int64
# recipient_state_code                                              object
# recipient_state_name                                              object
# recipient_zip_code                                                int64
# recipient_zip_last_4_code                                         float64
# prime_award_transaction_recipient_cd_original                     object
# prime_award_transaction_recipient_cd_current                      object
# recipient_foreign_city_name                                       float64
# recipient_foreign_province_name                                   float64
# recipient_foreign_postal_code                                     float64
# primary_place_of_performance_scope                                object
# primary_place_of_performance_country_code                         object
# primary_place_of_performance_country_name                         object
# primary_place_of_performance_code                                 object
# primary_place_of_performance_city_name                            object
# prime_award_transaction_place_of_performance_county_fips_code     float64
# primary_place_of_performance_county_name                          object
# prime_award_transaction_place_of_performance_state_fips_code      int64
# primary_place_of_performance_state_name                           object
# primary_place_of_performance_zip_4                                object
# prime_award_transaction_place_of_performance_cd_original          object
# prime_award_transaction_place_of_performance_cd_current           object
# primary_place_of_performance_foreign_location                     float64
# cfda_number                                                       float64
# cfda_title                                                        object
# funding_opportunity_number                                        object
# funding_opportunity_goals_text                                    object
# assistance_type_code                                              int64
# assistance_type_description                                       object
# transaction_description                                           object
# prime_award_base_transaction_description                          object
# business_funds_indicator_code                                     object
# business_funds_indicator_description                              object
# business_types_code                                               object
# business_types_description                                        object
# correction_delete_indicator_code                                  object
# correction_delete_indicator_description                           object
# action_type_code                                                  object
# action_type_description                                           object
# record_type_code                                                  int64
# record_type_description                                           object
# highly_compensated_officer_1_name                                 object
# highly_compensated_officer_1_amount                               float64
# highly_compensated_officer_2_name                                 object
# highly_compensated_officer_2_amount                               float64
# highly_compensated_officer_3_name                                 object
# highly_compensated_officer_3_amount                               float64
# highly_compensated_officer_4_name                                 object
# highly_compensated_officer_4_amount                               float64
# highly_compensated_officer_5_name                                 object
# highly_compensated_officer_5_amount                               float64
# usaspending_permalink                                             object
# initial_report_date                                               object
# last_modified_date                                                object
# fiscal_year                                                       object
# estimated_remaining_funds                                         float64
# spent_percent                                                     float64
# remaining_funds_percent                                           float64
# grant_is_open                                                     bool
# program_match__funding_code                                       object
# program_match__title                                              object
# program_match                                                     object
# dtypes: bool(1), datetime64[ns](3), float64(34), int64(9), object(73)
# memory usage: 44.2+ MB

# %% [markdown]
# ## Check matches and non-matches

# %%
contracts['program_match'].value_counts(dropna=False)
# Out:
# no match                                                     31405
# byrne memorial justice assistance grant                       9087
# victims of crime act (voca)                                   3310
# cops hiring program                                           1016
# second chance act community based re-entry program             812
# school violence prevention program                             770
# community policing development micro-grants                    717
# project safe neighborhood                                      708
# byrne criminal justice innovation                              152
# comunity violence intervention and prevention intitiative      152
# smart policing                                                  88
# strategies to support children exposed to violence              59
# Name: program_match, dtype: int64

# %%
contracts[contracts['program_match']=='no match']['cfda_title'].value_counts()
# Out:
# public safety partnership and community policing grants                                                                                                          2989
# coronavirus emergency supplemental funding program                                                                                                               2287
# national institute of justice research, evaluation, and development project grants                                                                               1812
# dna backlog reduction program                                                                                                                                    1445
# state criminal alien assistance program                                                                                                                          1059
# drug court discretionary grant program                                                                                                                           1028
# services for trafficking victims                                                                                                                                  982
# juvenile justice and delinquency prevention                                                                                                                       772
# violence against women formula grants                                                                                                                             762
# ovw technical assistance initiative                                                                                                                               738
# paul coverdell forensic sciences improvement grant program                                                                                                        731
#        'CPD', 'FY21 SCHOOL VIOLENCE PREVENTION PROGRAM (SVPP)',
#        'TRGP-E/T', 'CPD', 'TRGP-E/T',
#        'COPS ANTI-METHAMPHETAMINE PROGRAM (CAMP)',
#        'MAJOR DRUG TRAFFICKING ORGANIZATIONS (DTOS) ARE UNDOUBTEDLY THE LARGEST CONTRIBUTING FACTOR TO THE SUPPLY OF ILLICIT DRUGS IN THE STATE OF IOWA. MEXICAN DTOS ARE THE PRIMARY ORGANIZATIONAL THREAT TO THE STATE OF IOWA. METH CONTINUES TO BE THE LARGEST PROBLEM DRUG IN OUR STATE. METH IS HIGHLY AVAILABLE IN THE STATE OF IOWA. METH TREATMENT ADMISSIONS HAVE STEADILY INCREASED OVER THE PAST NINE YEARS. DOMESTIC MANUFACTURING OF METH, SPECIFICALLY “ONE-POT” LABS REMAINS A THREAT TO PUBLIC SAFETY, DESPITE THE FACT THAT THEY CONTRIBUTE A FRACTIONAL SUPPLY OF METH IN COMPARISON WITH THE MEXICAN DTOSIOWA HAS MADE GREAT PROGRESS IN DEALING WITH A METH EPIDEMIC THAT STARTED IN THE 1990S. WE HAVE, IN RECENT YEARS HOWEVER BEGUN TO LOSE GROUND. SEIZURES ARE TRENDING UPWARD, SEIZURES ARE LARGER AND SIGNIFICANTLY MORE PURE, ARRESTS AND INCARCERATION RATES ARE INCREASING, AND USAGE RATES ARE BEGINNING TO TREND UP AGAIN. NOT ALL OF THE SLIPPAGE IN IOWA METH TRENDS HAS A LAW ENFORCEMENT SOLUTION, HOWEVER THIS PROPOSAL REQUEST FUNDING TO RESPOND DIRECTLY TO THE MOST PRESSING ISSUES FOR THE ENFORCEMENT COMMUNITY. THIS PROPOSAL WILL ADDRESS THE FOLLOWING 3 PRIORITIES: DRUG ENFORCEMENT TASK FORCE OVERTIMEIOWA HAS ESTABLISHED A NETWORK OF DRUG ENFORCEMENT TASK FORCES THROUGH THE JUSTICE ASSISTANCE GRANT (JAG). THERE ARE CURRENTLY 16 LOCAL TASK FORCES ALONG WITH ONE STATE TASK FORCE FUNDED THROUGH THIS PROGRAM. LOCAL TASK FORCES AND THE IOWA DIVISION OF NARCOTICS ENFORCEMENT (DNE) HAVE AN EXCELLENT WORKING RELATIONSHIP. THE DNE ESTIMATES THAT ABOUT 85% OF THEIR CASES ARE EITHER WORKED JOINTLY WITH OR INITIATED AND HANDED OFF FROM LOCAL DRUG TASK FORCES. UNFORTUNATELY, THE BYRNE JUSTICE ASSISTANCE GRANT PROGRAM HAS SEEN A 43% REDUCTION IN FUNDING OVER THE PAST SEVERAL YEARS RESULTING IN SIGNIFICANT DOWNSIZING. AS A RESULT, LOCAL ENFORCEMENT PROJECTS ARE FORCED TO PRIORITIZE CASES. WHILE LOCAL OFFICERS ARE INCLINED TO WORK CASES TO THEIR HIGHEST POTENTIAL, PRESSURE FROM THE COMMUNITY REQUIRES THAT THEY FOCUS ON CASES WITH A PHYSICAL PRESENCE IN THE COMMUNITY. GRANT FUNDING IS REQUESTED TO SUPPORT TASK FORCES IN A WAY THAT ENCOURAGES THE DEVELOPMENT OF CASES WHICH CAN BE WORKED UP THE DISTRIBUTION CHAIN. INTELLIGENCE SHARINGTHE TRANSIENT NATURE OF THE DRUG TRADE NECESSITATES THE NEED FOR MULTIJURISDICTIONAL DRUG ENFORCEMENT TASK FORCES AND EFFECTIVE INFORMATION SHARING. TASK FORCES ACROSS THE NATION STRUGGLE WITH SUBJECT OR TARGET DECONFLICTION. THIS PROJECT WILL INCORPORATE INTELLIGENCE SUBMISSIONS/TARGET DE-CONFLICTION INTO THE NORMAL OPERATING PROCEDURES OF PARTICIPATING TASK FORCE AGENCIES. PSEUDOEPHEDRINE TRACKINGTHE NATIONAL PRECURSOR LOG EXCHANGE (NPLEX) IS FULLY IMPLEMENTED WITH 891 REGISTERED ENFORCEMENT USERS AND 656 PHARMACISTS. GRANT FUNDING WILL BE USED TO FUND A PART TIME PROGRAM COORDINATOR TO PROVIDE DIRECT ASSISTANCE WITH TECHNICAL SUPPORT, CERTIFIED RECORDS, EDUCATION, EXPERT TESTIMONY, REGISTRATION, OR SYSTEM QUESTIONS.',
#        'GREENVILLE, SC POLICE PROJECT SAFE NEIGHBORHOOD EXPANSION', 'CHP'],
#       dtype=object)

# %% [markdown]
# # Only retain useful columns

# %%
keep_cols = [
    'usaspending_permalink',
    'fiscal_year',
    'total_obligated_amount',
    'estimated_remaining_funds',
    'spent_percent',
    'grant_is_open',
    'program_match',
    'business_types_description',
    'prime_award_base_transaction_description',
    'transaction_description',
    'funding_opportunity_goals_text',
    'cfda_title',
    'cfda_number',
    'primary_place_of_performance_scope',
    'primary_place_of_performance_city_name',
    'primary_place_of_performance_state_name',
    'primary_place_of_performance_zip_4',
    'recipient_name',
    'funding_agency_name',
    'period_of_performance_start_date',
    'period_of_performance_current_end_date',
    'assistance_award_unique_key',
    'action_date'
]

# %% [markdown]
# # De-duplicate

# %%
dup_cols = [
    'usaspending_permalink',
]

contracts.sort_values(by='action_date',ascending=True,inplace=True)

contracts.drop_duplicates(subset=dup_cols,keep='last',inplace=True)

# %% [markdown]
# # Write out

# %%
contracts[keep_cols].to_parquet('clean_data/clean_doj_contracts.parquet')

# %% [markdown]
# # QA

# %%
contracts[contracts['usaspending_permalink']=='https://www.usaspending.gov/award/ASST_NON_2017GPBX0001_1550/']
# Out:
#          assistance_transaction_unique_key assistance_award_unique_key  \
# 5414  1550_2017GPBX0001_-NONE-_16.609_00-3  ASST_NON_2017GPBX0001_1550
#
#      award_id_fain modification_number award_id_uri         sai_number  \
# 5414  2017GPBX0001                00-3          NaN  SAI NOT AVAILABLE
#
#       federal_action_obligation  total_obligated_amount  \
# 5414                       -0.1                499442.9
#
#       total_outlayed_amount_for_overall_award  \
# 5414                                352570.88
#
#       indirect_cost_federal_share_amount  non_federal_funding_amount  \
# 5414                                 0.0                         0.0
#
#       total_non_federal_funding_amount  face_value_of_loan  \
# 5414                               0.0                 0.0
#
#       original_loan_subsidy_cost  total_face_value_of_loan  \
# 5414                         0.0                       0.0
#
#       total_loan_subsidy_cost  generated_pragmatic_obligations  \
# 5414                      0.0                             -0.1
#
#                              disaster_emergency_fund_codes_for_overall_award  \
# 5414  Q: Not Designated Nonemergency/Emergency/Disaster/Wildfire Suppression
#
#       outlayed_amount_from_COVID-19_supplementals_for_overall_award  \
# 5414                                                            NaN
#
#       obligated_amount_from_COVID-19_supplementals_for_overall_award  \
# 5414                                                             NaN
#
#       outlayed_amount_from_IIJA_supplemental_for_overall_award  \
# 5414                                                       NaN
#
#       obligated_amount_from_IIJA_supplemental_for_overall_award action_date  \
# 5414                                                        NaN  2022-02-14
#
#       action_date_fiscal_year period_of_performance_start_date  \
# 5414                     2022                       2017-10-01
#
#      period_of_performance_current_end_date  awarding_agency_code  \
# 5414                             2021-02-28                    15
#
#        awarding_agency_name  awarding_sub_agency_code  \
# 5414  Department of Justice                      1550
#
#         awarding_sub_agency_name awarding_office_code  \
# 5414  Office of Justice Programs               15PBJA
#
#                   awarding_office_name  funding_agency_code  \
# 5414  OJP BUREAU OF JUSTICE ASSISTANCE                 15.0
#
#         funding_agency_name  funding_sub_agency_code  \
# 5414  Department of Justice                   1550.0
#
#          funding_sub_agency_name funding_office_code  \
# 5414  Office of Justice Programs              15PBJA
#
#                    funding_office_name treasury_accounts_funding_this_award  \
# 5414  OJP BUREAU OF JUSTICE ASSISTANCE                       015-X-0404-000
#
#      federal_accounts_funding_this_award  \
# 5414                            015-0404
#
#                object_classes_funding_this_award  \
# 5414  41.0: Grants, subsidies, and contributions
#
#                                                                    program_activities_funding_this_award  \
# 5414  0043: PROJECT SAFE NEIGHBORHOODS;0043: S&L GUN CRIME PROSECUTION ASSISTANCE/GUN VIOLENCE REDUCTION
#
#      recipient_uei  recipient_duns   recipient_name recipient_name_raw  \
# 5414  P138LY34M6L6             NaN  CITY OF CHICAGO    CITY OF CHICAGO
#
#      recipient_parent_uei  recipient_parent_duns recipient_parent_name  \
# 5414                  NaN                    NaN       CITY OF CHICAGO
#
#      recipient_parent_name_raw recipient_country_code recipient_country_name  \
# 5414           CITY OF CHICAGO                    USA          UNITED STATES
#
#      recipient_address_line_1 recipient_address_line_2 recipient_city_code  \
# 5414      3510 S MICHIGAN AVE                      NaN               14000
#
#      recipient_city_name  prime_award_transaction_recipient_county_fips_code  \
# 5414             CHICAGO                                               17031
#
#      recipient_county_name  prime_award_transaction_recipient_state_fips_code  \
# 5414                  COOK                                                 17
#
#      recipient_state_code recipient_state_name  recipient_zip_code  \
# 5414                   IL             ILLINOIS               60653
#
#       recipient_zip_last_4_code prime_award_transaction_recipient_cd_original  \
# 5414                     1020.0                                         IL-01
#
#      prime_award_transaction_recipient_cd_current  \
# 5414                                        IL-01
#
#       recipient_foreign_city_name  recipient_foreign_province_name  \
# 5414                          NaN                              NaN
#
#       recipient_foreign_postal_code primary_place_of_performance_scope  \
# 5414                            NaN                    SINGLE ZIP CODE
#
#      primary_place_of_performance_country_code  \
# 5414                                       USA
#
#      primary_place_of_performance_country_name  \
# 5414                             UNITED STATES
#
#      primary_place_of_performance_code primary_place_of_performance_city_name  \
# 5414                           IL14000                                CHICAGO
#
#       prime_award_transaction_place_of_performance_county_fips_code  \
# 5414                                                        17031.0
#
#      primary_place_of_performance_county_name  \
# 5414                                     COOK
#
#       prime_award_transaction_place_of_performance_state_fips_code  \
# 5414                                                            17
#
#      primary_place_of_performance_state_name  \
# 5414                                ILLINOIS
#
#      primary_place_of_performance_zip_4  \
# 5414                         60653-1020
#
#      prime_award_transaction_place_of_performance_cd_original  \
# 5414                                                    IL-01
#
#      prime_award_transaction_place_of_performance_cd_current  \
# 5414                                                   IL-01
#
#       primary_place_of_performance_foreign_location  cfda_number  \
# 5414                                            NaN       16.609
#
#                       cfda_title funding_opportunity_number  \
# 5414  project safe neighborhoods             BJA-2017-11482
#
#      funding_opportunity_goals_text  assistance_type_code  \
# 5414                            NaN                     4
#
#      assistance_type_description  \
# 5414           PROJECT GRANT (B)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   transaction_description  \
# 5414  AS PART OF BJAS SMART SUITE, THE PROJECT SAFE NEIGHBORHOODS (PSN), REPRESENTS A STRATEGIC APPROACH THAT BRINGS MORE SCIENCE INTO CRIMINAL JUSTICE OPERATIONS BY LEVERAGING INNOVATIVE APPLICATIONS OF ANALYSIS, TECHNOLOGY, AND EVIDENCE-BASED PRACTICES WITH THE GOAL OF IMPROVING PERFORMANCE AND EFFECTIVENESS WHILE CONTAINING COSTS. THE PROGRAM'S EFFECTIVENESS IS BASED ON THE COOPERATION OF LOCAL, STATE, AND FEDERAL AGENCIES ENGAGED IN A UNIFIED APPROACH LED BY THE U.S. ATTORNEY (USA) IN EACH ...
#
#                                              prime_award_base_transaction_description  \
# 5414  NORTHERN DISTRICT OF ILLINOIS FY17 VIOLENT GANG AND GUN CRIME REDUCTION PROGRAM
#
#      business_funds_indicator_code business_funds_indicator_description  \
# 5414                           NON                     NOT RECOVERY ACT
#
#      business_types_code   business_types_description  \
# 5414                   C  CITY OR TOWNSHIP GOVERNMENT
#
#      correction_delete_indicator_code correction_delete_indicator_description  \
# 5414                              NaN                                     NaN
#
#      action_type_code          action_type_description  record_type_code  \
# 5414                D  ADJUSTMENT TO COMPLETED PROJECT                 2
#
#      record_type_description highly_compensated_officer_1_name  \
# 5414    NON-AGGREGATE RECORD                               NaN
#
#       highly_compensated_officer_1_amount highly_compensated_officer_2_name  \
# 5414                                  NaN                               NaN
#
#       highly_compensated_officer_2_amount highly_compensated_officer_3_name  \
# 5414                                  NaN                               NaN
#
#       highly_compensated_officer_3_amount highly_compensated_officer_4_name  \
# 5414                                  NaN                               NaN
#
#       highly_compensated_officer_4_amount highly_compensated_officer_5_name  \
# 5414                                  NaN                               NaN
#
#       highly_compensated_officer_5_amount  \
# 5414                                  NaN
#
#                                               usaspending_permalink  \
# 5414  https://www.usaspending.gov/award/ASST_NON_2017GPBX0001_1550/
#
#      initial_report_date last_modified_date fiscal_year  \
# 5414          2023-04-11         2023-04-11        2022
#
#       estimated_remaining_funds  spent_percent  remaining_funds_percent  \
# 5414                  146872.02           71.0                     29.0
#
#       grant_is_open program_match__funding_code       program_match__title  \
# 5414          False   project safe neighborhood  project safe neighborhood
#
#                   program_match
# 5414  project safe neighborhood
