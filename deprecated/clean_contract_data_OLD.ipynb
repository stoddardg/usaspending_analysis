# %%
import pandas as pd
pd.options.display.max_columns=200
pd.options.display.max_rows=500
pd.options.display.max_colwidth=500

# from thefuzz import fuzz
# from thefuzz import process

from datetime import datetime

from glob import glob
import re

# %%
LIMIT_TO_OPEN_GRANTS = False
LIMIT_TO_RELEVANT_GRANTS = True
LIMIT_TO_NEW_ENTRIES_ONLY = True
REMOVE_STATE_GOVTS = True

def normalize_program_names(_df, title_col = 'cfda_title'):
    df = _df.copy()
    df[title_col] = df[title_col].str.lower()
    df[title_col] = df[title_col].fillna('none')

    return df

# %%
def get_year(file_path):

    pattern = r'FY(\d{4})'

    # Search for the pattern in the string
    match = re.search(pattern, file_path)

    if match:
        year = match.group(1)
        return year
    else:
        return 1900

# %%
import re

all_data = []
for g in glob('usa_spending_contract_data/FY*/*',recursive=True):
    temp_data = pd.read_csv(g)
    temp_data['fiscal_year'] = get_year(g)
    all_data.append(temp_data)

raw_contracts = pd.concat(all_data)


# raw_contracts = pd.read_csv('usa_spending_contract_data/FY2019/All_Assistance_PrimeTransactions_2024-05-28_H10M16S23_1.csv')
# # raw_contracts = pd.read_csv('usa_spending_contract_data/FY2024/All_Assistance_PrimeTransactions_2024-05-28_H01M15S04_1.csv')
# Out:
# C:\Users\orent\miniconda3\envs\crime-lab\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
contracts = normalize_program_names(raw_contracts)

# %%
contracts['total_outlayed_amount_for_overall_award'] = contracts['total_outlayed_amount_for_overall_award'].fillna(0)

contracts['estimated_remaining_funds'] = contracts['total_obligated_amount'] - contracts['total_outlayed_amount_for_overall_award']

contracts['spent_percent'] = ((contracts['total_outlayed_amount_for_overall_award'] / contracts['total_obligated_amount'])*100).round(0)

contracts['remaining_funds_percent'] = ((contracts['estimated_remaining_funds'] / contracts['total_obligated_amount'])*100).round(0)

contracts['period_of_performance_current_end_date'] = pd.to_datetime(contracts['period_of_performance_current_end_date'])

contracts['period_of_performance_start_date'] = pd.to_datetime(contracts['period_of_performance_start_date'])
contracts['action_date'] = pd.to_datetime(contracts['action_date'])


contracts['grant_is_open'] = contracts['period_of_performance_current_end_date'] >= datetime(2024,9,1)


contracts['program_activities_funding_this_award'] = contracts['program_activities_funding_this_award'].fillna('missing')

# %% [markdown]
# # Code program names

# %%
program_map = {
    'comunity violence intervention and prevention intitiative':
        ['0153: COMMUNITY-BASED VIOLENCE PREVENTION INITIATIVES',
        #'public safety partnership and community policing grants',
        'community-based violence prevention program'],
    'victims of crime act (voca)':['0001: CRIME VICTIMS GRANTS AND ASSISTANCE','0006: TRIBAL VICTIMS ASSISTANCE GRANTS'],
    'center for culturally responsive victim services':[],
    'byrne memorial justice assistance grant':['0007: JUSTICE ASSISTANCE GRANTS','edward byrne memorial justice assistance grant program'],
    'byrne criminal justice innovation':['0081: COMMUNITY BASED CRIME REDUCTION PROGRAM (BYRNE CRIMINAL JUSTICE INNOVATION)'],
    'strategies to support children exposed to violence':['0024: CHILDREN EXPOSED TO VIOLENCE','children exposed to violence'],
    'project safe neighborhood':['0043: PROJECT SAFE NEIGHBORHOODS','project safe neighborhoods'],
    'youth violence and reductions':[],
    'school violence prevention program':['0143: STOP SCHOOL VIOLENCE ACT'],
    'second chance act community based re-entry program':['0050: SECOND CHANCE ACT/OFFENDER REENTRY'],
    'community policing development micro-grants':['0001: PUBLIC SAFETY AND COMMUNITY POLICING GRANTS'],
    'smart policing':['0021: STRATEGIES FOR POLICING INNOVATION'],
    'cops hiring program':['0009: COPS HIRING PROGRAM']
}

# %%
def match_grant_program_to_map(x):
    if x is None:
        return 'other'

    program_matches = []
    for program_name, program_list in program_map.items():

        for program_code in program_list:
            if x.find(program_code) != -1:
                program_matches.append(program_name)
    
    # if len(program_matches) > 1:
    #     print(f"MULTIPLE MATCHES FOR {x}")
        
    
    if len(program_matches) == 0:
        return "other"

    return program_matches[0]

# %%
contracts["program_match__funding_code"] = contracts[
    "program_activities_funding_this_award"
].apply(match_grant_program_to_map)

contracts["program_match__title"] = contracts["cfda_title"].apply(
    match_grant_program_to_map
)
contracts["program_match"] = contracts["program_match__funding_code"].where(
    contracts["program_match__funding_code"] != "other",
    contracts["program_match__title"],
)

# %%
contracts.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48276 entries, 0 to 1850
# Data columns (total 120 columns):
#  #    Column                                                          Dtype
# ---   ------                                                          -----
#  0    assistance_transaction_unique_key                               object
#  1    assistance_award_unique_key                                     object
#  2    award_id_fain                                                   object
#  3    modification_number                                             object
#  4    award_id_uri                                                    object
#  5    sai_number                                                      object
#  6    federal_action_obligation                                       float64
#  7    total_obligated_amount                                          float64
#  8    total_outlayed_amount_for_overall_award                         float64
#  9    indirect_cost_federal_share_amount                              float64
#  10   non_federal_funding_amount                                      float64
#  11   total_non_federal_funding_amount                                float64
#  12   face_value_of_loan                                              float64
#  13   original_loan_subsidy_cost                                      float64
#  14   total_face_value_of_loan                                        float64
#  15   total_loan_subsidy_cost                                         float64
#  16   generated_pragmatic_obligations                                 float64
#  17   disaster_emergency_fund_codes_for_overall_award                 object
#  18   outlayed_amount_from_COVID-19_supplementals_for_overall_award   float64
#  19   obligated_amount_from_COVID-19_supplementals_for_overall_award  float64
#  20   outlayed_amount_from_IIJA_supplemental_for_overall_award        float64
#  21   obligated_amount_from_IIJA_supplemental_for_overall_award       float64
#  22   action_date                                                     datetime64[ns]
#  23   action_date_fiscal_year                                         int64
#  24   period_of_performance_start_date                                datetime64[ns]
#  25   period_of_performance_current_end_date                          datetime64[ns]
#  26   awarding_agency_code                                            int64
#  27   awarding_agency_name                                            object
#  28   awarding_sub_agency_code                                        int64
#  29   awarding_sub_agency_name                                        object
#  30   awarding_office_code                                            object
#  31   awarding_office_name                                            object
#  32   funding_agency_code                                             float64
#  33   funding_agency_name                                             object
#  34   funding_sub_agency_code                                         float64
#  35   funding_sub_agency_name                                         object
#  36   funding_office_code                                             object
#  37   funding_office_name                                             object
#  38   treasury_accounts_funding_this_award                            object
#  39   federal_accounts_funding_this_award                             object
#  40   object_classes_funding_this_award                               object
#  41   program_activities_funding_this_award                           object
#  42   recipient_uei                                                   object
#  43   recipient_duns                                                  float64
#  44   recipient_name                                                  object
#  45   recipient_name_raw                                              object
#  46   recipient_parent_uei                                            object
#  47   recipient_parent_duns                                           float64
#  48   recipient_parent_name                                           object
#  49   recipient_parent_name_raw                                       object
#  50   recipient_country_code                                          object
#  51   recipient_country_name                                          object
#  52   recipient_address_line_1                                        object
#  53   recipient_address_line_2                                        object
#  54   recipient_city_code                                             object
#  55   recipient_city_name                                             object
#  56   prime_award_transaction_recipient_county_fips_code              int64
#  57   recipient_county_name                                           object
#  58   prime_award_transaction_recipient_state_fips_code               int64
#  59   recipient_state_code                                            object
#  60   recipient_state_name                                            object
#  61   recipient_zip_code                                              int64
#  62   recipient_zip_last_4_code                                       float64
#  63   prime_award_transaction_recipient_cd_original                   object
#  64   prime_award_transaction_recipient_cd_current                    object
#  65   recipient_foreign_city_name                                     float64
#  66   recipient_foreign_province_name                                 float64
#  67   recipient_foreign_postal_code                                   float64
#  68   primary_place_of_performance_scope                              object
#  69   primary_place_of_performance_country_code                       object
#  70   primary_place_of_performance_country_name                       object
#  71   primary_place_of_performance_code                               object
#  72   primary_place_of_performance_city_name                          object
#  73   prime_award_transaction_place_of_performance_county_fips_code   float64
#  74   primary_place_of_performance_county_name                        object
#  75   prime_award_transaction_place_of_performance_state_fips_code    int64
#  76   primary_place_of_performance_state_name                         object
#  77   primary_place_of_performance_zip_4                              object
#  78   prime_award_transaction_place_of_performance_cd_original        object
#  79   prime_award_transaction_place_of_performance_cd_current         object
#  80   primary_place_of_performance_foreign_location                   float64
#  81   cfda_number                                                     float64
#  82   cfda_title                                                      object
#  83   funding_opportunity_number                                      object
#  84   funding_opportunity_goals_text                                  object
#  85   assistance_type_code                                            int64
#  86   assistance_type_description                                     object
#  87   transaction_description                                         object
#  88   prime_award_base_transaction_description                        object
#  89   business_funds_indicator_code                                   object
#  90   business_funds_indicator_description                            object
#  91   business_types_code                                             object
#  92   business_types_description                                      object
#  93   correction_delete_indicator_code                                object
#  94   correction_delete_indicator_description                         object
#  95   action_type_code                                                object
#  96   action_type_description                                         object
#  97   record_type_code                                                int64
#  98   record_type_description                                         object
#  99   highly_compensated_officer_1_name                               object
#  100  highly_compensated_officer_1_amount                             float64
#  101  highly_compensated_officer_2_name                               object
#  102  highly_compensated_officer_2_amount                             float64
#  103  highly_compensated_officer_3_name                               object
#  104  highly_compensated_officer_3_amount                             float64
#  105  highly_compensated_officer_4_name                               object
#  106  highly_compensated_officer_4_amount                             float64
#  107  highly_compensated_officer_5_name                               object
#  108  highly_compensated_officer_5_amount                             float64
#  109  usaspending_permalink                                           object
#  110  initial_report_date                                             object
#  111  last_modified_date                                              object
#  112  fiscal_year                                                     object
#  113  estimated_remaining_funds                                       float64
#  114  spent_percent                                                   float64
#  115  remaining_funds_percent                                         float64
#  116  grant_is_open                                                   bool
#  117  program_match__funding_code                                     object
#  118  program_match__title                                            object
#  119  program_match                                                   object
# dtypes: bool(1), datetime64[ns](3), float64(34), int64(9), object(73)
# memory usage: 44.2+ MB

# %% [markdown]
# ## Check matches and non-matches

# %%
contracts['program_match'].value_counts(dropna=False)
# Out:
# other                                                        31405
# byrne memorial justice assistance grant                       9087
# victims of crime act (voca)                                   3310
# cops hiring program                                           1016
# second chance act community based re-entry program             812
# school violence prevention program                             770
# community policing development micro-grants                    717
# project safe neighborhood                                      708
# comunity violence intervention and prevention intitiative      152
# byrne criminal justice innovation                              152
# smart policing                                                  88
# strategies to support children exposed to violence              59
# Name: program_match, dtype: int64

# %%
contracts[contracts['program_match']=='other']['cfda_title'].value_counts()
# Out:
# public safety partnership and community policing grants                                                                                                          2989
# coronavirus emergency supplemental funding program                                                                                                               2287
# national institute of justice research, evaluation, and development project grants                                                                               1812
# dna backlog reduction program                                                                                                                                    1445
# state criminal alien assistance program                                                                                                                          1059
# drug court discretionary grant program                                                                                                                           1028
# services for trafficking victims                                                                                                                                  982
# juvenile justice and delinquency prevention                                                                                                                       772
# violence against women formula grants                                                                                                                             762
# ovw technical assistance initiative                                                                                                                               738
# paul coverdell forensic sciences improvement grant program                                                                                                        731
# transitional housing assistance for victims of domestic violence, dating violence, stalking, or sexual assault                                                    676
# state domestic violence and sexual assault coalitions                                                                                                             657
# missing children's assistance                                                                                                                                     619
# sexual assault services formula program                                                                                                                           616
# congressionally recommended awards                                                                                                                                574
# violence against women discretionary grants for indian tribal governments                                                                                         539
# john r.  justice prosecutors and defenders incentive act                                                                                                          539
# legal assistance for victims                                                                                                                                      536
# criminal and juvenile justice and mental health collaboration program                                                                                             536
# national criminal history improvement program (nchip)                                                                                                             527
# grants to reduce domestic violence, dating violence, sexual assault, and stalking on campus                                                                       522
# grants to encourage arrest policies and enforcement of protection orders program                                                                                  515
# support for adam walsh act implementation grant program                                                                                                           514
# residential substance abuse treatment for state prisoners                                                                                                         512
# rural domestic violence, dating violence, sexual assault, and stalking assistance program                                                                         491
# body worn camera policy and implementation                                                                                                                        474
# comprehensive opioid, stimulant, and substance abuse program                                                                                                      461
# juvenile mentoring program                                                                                                                                        436
# state justice statistics program for statistical analysis centers                                                                                                 374
# special data collections and statistical studies                                                                                                                  324
# national sexual assault kit initiative                                                                                                                            307
# tribal justice systems and alcohol and substance abuse                                                                                                            300
# prea program: strategic support for prea implementation                                                                                                           260
# harold rogers prescription drug monitoring program                                                                                                                257
# culturally and linguistically specific services program                                                                                                           249
# nics act record improvement program                                                                                                                               248
# justice systems response to families                                                                                                                              240
# consolidated and technical assistance grant program to address children and youth experiencing domestic and sexual violence and engage men and boys as allies     229
# tribal domestic violence and sexual assault coalitions grant program                                                                                              220
# justice system infrastructure program for indian tribes                                                                                                           189
# justice reinvestment initiative                                                                                                                                   176
# tribal youth program                                                                                                                                              164
# comprehensive opioid, stimulant, and other substances use program                                                                                                 162
# treatment court discretionary grant program                                                                                                                       150
# second chance act reentry initiative                                                                                                                              149
# capital case litigation initiative                                                                                                                                136
# grants for outreach and services to underserved populations                                                                                                       131
# education, training, and enhanced services to end violence against and abuse of women with disabilities                                                           130
# smart prosecution initiative                                                                                                                                      128
# comprehensive opioid abuse site-based program                                                                                                                     116
# sexual assault services culturally specific program                                                                                                               107
# enhanced training and services to end violence and abuse of women later in life                                                                                   106
# postconviction testing of dna evidence                                                                                                                            106
# economic, high-tech, and cyber crime prevention                                                                                                                    98
# community-based violence intervention and prevention initiative                                                                                                    96
# office on violence against women special projects                                                                                                                  94
# missing alzheimer's disease patient assistance program                                                                                                             89
# stop school violence                                                                                                                                               84
# tribal sexual assault services program                                                                                                                             83
# ovw research and evaluation program                                                                                                                                82
# children of incarcerated parents                                                                                                                                   80
# opioid affected youth initiative                                                                                                                                   74
# special domestic violence criminal jurisdiction implementation                                                                                                     74
# improving the investigation and prosecution of child abuse and the regional and local children's advocacy centers                                                  74
# voca tribal victim services set-aside program                                                                                                                      69
# edward byrne memorial competitive grant program                                                                                                                    63
# girls in the juvenile justice system                                                                                                                               61
# tribal justice systems                                                                                                                                             58
# indigent defense                                                                                                                                                   51
# veterans treatment court discretionary grant program                                                                                                               51
# rural violent crime initiative                                                                                                                                     49
# forensics training and technical assistance program                                                                                                                43
# matthew shepard and james byrd, jr. hate crimes education, investigation and prosecution program                                                                   43
# crime victim assistance/discretionary grants                                                                                                                       41
# innovative responses to behavior in the community: swift, certain, and fair supervision program                                                                    35
# criminal justice research and development graduate research fellowships                                                                                            33
# regional information sharing systems                                                                                                                               31
# emergency planning for juvenile justice facilities                                                                                                                 31
# delinquency prevention program                                                                                                                                     31
# national institute of justice w.e.b. dubois fellowship program                                                                                                     31
# emergency law enforcement assistance grant                                                                                                                         29
# gulf states regional law enforcement technology training and technical assistance initiative                                                                       27
# community-based approaches to advancing justice                                                                                                                    26
# prosecuting cold cases using dna                                                                                                                                   24
# swift, certain, and fair supervision program: applying the principles behind project hope                                                                          24
# tribal civil and criminal legal assistance grants, training and technical assistance                                                                               23
# strengthening the medical examiner - coroner system                                                                                                                21
# public safety officers' benefits program                                                                                                                           15
# title v delinquency prevention program                                                                                                                             15
# missing and unidentified human remains (muhr) program                                                                                                              14
# domestic trafficking victim program                                                                                                                                14
# emmett till cold case investigations program                                                                                                                       14
# combatting contraband cell phone use in prisons                                                                                                                    13
# preventing trafficking of girls                                                                                                                                    13
# vision 21                                                                                                                                                          11
# promoting evidence integration in sex offender management discretionary grant program                                                                              11
# supporting vulnerable and at-risk youth transitioning out of foster care                                                                                           11
# supervised visitation, safe havens for children                                                                                                                    10
# juvenile accountability block grants                                                                                                                               10
# khalid jabara and heather heyer no hate act                                                                                                                        10
# national clearinghouse on sexual assault of american indian and alaska native women                                                                                 9
# resource center on workplace response to domestic violence, dating violence, sexual assault, and stalking                                                           7
# national prison rape statistics program                                                                                                                             7
# judicial training on child maltreatment for court personnel juvenile justice programs                                                                               7
# youth gang prevention                                                                                                                                               7
# keep young athletes safe                                                                                                                                            6
# sexual assault forensic examinations                                                                                                                                5
# tribal special assistant united states attorneys                                                                                                                    5
# innovations in community-based crime reduction                                                                                                                      5
# crime victim assistance                                                                                                                                             4
# state and local anti-terrorism training                                                                                                                             4
# national center on restorative justice                                                                                                                              4
# juvenile justice education collaboration assistance                                                                                                                 3
# national ashanti alert network training and technical assistance program                                                                                            3
# indian country alcohol and drug prevention                                                                                                                          3
# swift, certain, and fair (scf) supervision program: including project hope                                                                                          3
# enforcing underage drinking laws program                                                                                                                            3
# violence against women act court training and improvement grants                                                                                                    3
# court appointed special advocates                                                                                                                                   3
# drug data research center to combat the opioid crisis                                                                                                               2
# crime gun intelligence training and education                                                                                                                       2
# crime victim compensation                                                                                                                                           2
# comprehensive forensic dna analysis grant program                                                                                                                   2
# trible justice assistance                                                                                                                                           2
# juvenile justice reform and reinvestment demonstration program                                                                                                      2
# president-elect security assistance reimbursement grant program                                                                                                     2
# national deaf services line                                                                                                                                         1
# engaging men and youth in preventing domestic violence, dating violence, sexual assault, and stalking                                                               1
# community capacity development office                                                                                                                               1
# public safety interoperable communications grant program                                                                                                            1
# edward byrne memorial state and local law enforcement assistance discretionary grants program                                                                       1
# national decertification index                                                                                                                                      1
# part e - developing, testing and demonstrating promising new programs                                                                                               1
# academic-based drug field testing and training initiative                                                                                                           1
# virtual reality de-escalation training                                                                                                                              1
# Name: cfda_title, dtype: int64

# %%
contracts[contracts['cfda_title']=='public safety partnership and community policing grants']['transaction_description'].sample(10).values
# Out:
# array(['COP ENHANCEMENT 2018', 'HOPING TO HIRE ONE POLICE OFFICER', 'CHP',
#        'TRGP-HIRE', 'CHP', 'SVPP',
#        'SAVANNAH- CHATAM COUNTY OF BOARD OF EDUCATION IS PROPOSING TO PROVIDE CIT TRAINING TO ALL SROS TO PROVIDE AN EFFICIENT RESPONSE TO ALL INCIDENT REQUIRING CRISIS INTERVENTION. THEY ALSO PLAN TO PARTNER WILL LOCAL AGENCIES SUCH AS THE DEPARTMENT OF FAMILY AND CHILDREN SERVICES, ALL LOCAL YOUTH AND FAMILY PROGRAMS, ALL LOCAL LAW ENFORCEMENT AGENCIES IN CHATHAM COUNTY, GEORGIA, AND RAPE CRISIS CENTERS. THE BOEPD WILL ALSO PARTNER WITH THE DEPARTMENT OF JUVENILE JUSTICE AND JUVENILE COURT.',
#        'ANACONDA-DEER LODGE COUNTY/ANACONDA SCHOOLS - SCHOOL RESOURCE OFFICER PROJECT',
#        'COPS OFFICE ANTI-HEROIN TASK FORCE PROGRAM (AHTF)',
#        'PULLMAN, WA LEMHWA PROJECT'], dtype=object)

# %% [markdown]
# # Only retain useful columns

# %%
keep_cols = [
    'usaspending_permalink',
    'fiscal_year',
    'total_obligated_amount',
    'estimated_remaining_funds',
    'spent_percent',
    'grant_is_open',
    'program_match',
    'business_types_description',
    'prime_award_base_transaction_description',
    'transaction_description',
    'funding_opportunity_goals_text',
    'cfda_title',
    'cfda_number',
    'primary_place_of_performance_scope',
    'primary_place_of_performance_city_name',
    'primary_place_of_performance_state_name',
    'primary_place_of_performance_zip_4',
    'recipient_name',
    'funding_agency_name',
    'period_of_performance_start_date',
    'period_of_performance_current_end_date',
    'assistance_award_unique_key',
    'action_date'
]

# %% [markdown]
# # De-duplicate & Final Processing

# %%
# Use filters for open and program match grants

if LIMIT_TO_OPEN_GRANTS:
    contracts = contracts[contracts['grant_is_open']==True]

if LIMIT_TO_NEW_ENTRIES_ONLY:
    contracts = contracts[contracts['action_type_description'] == 'NEW']

if REMOVE_STATE_GOVTS:
    contracts = contracts[contracts['business_types_description'] != 'STATE GOVERNMENT']

# %%
dup_cols = [
    'usaspending_permalink',
]

contracts.sort_values(by='action_date',ascending=True,inplace=True)

contracts.drop_duplicates(subset=dup_cols,keep='last',inplace=True)

# %% [markdown]
# # Write out

# %%
contracts[keep_cols].to_parquet('clean_data/clean_doj_all_contracts.parquet')

if LIMIT_TO_RELEVANT_GRANTS:
    contracts = contracts[contracts['program_match'] != 'other']

contracts[keep_cols].to_parquet('clean_data/clean_doj_contracts.parquet')

# %% [markdown]
# # QA

# %%
contracts[contracts['usaspending_permalink']=='https://www.usaspending.gov/award/ASST_NON_2017GPBX0001_1550/']
# Out:
# Empty DataFrame
# Columns: [assistance_transaction_unique_key, assistance_award_unique_key, award_id_fain, modification_number, award_id_uri, sai_number, federal_action_obligation, total_obligated_amount, total_outlayed_amount_for_overall_award, indirect_cost_federal_share_amount, non_federal_funding_amount, total_non_federal_funding_amount, face_value_of_loan, original_loan_subsidy_cost, total_face_value_of_loan, total_loan_subsidy_cost, generated_pragmatic_obligations, disaster_emergency_fund_codes_for_overall_award, outlayed_amount_from_COVID-19_supplementals_for_overall_award, obligated_amount_from_COVID-19_supplementals_for_overall_award, outlayed_amount_from_IIJA_supplemental_for_overall_award, obligated_amount_from_IIJA_supplemental_for_overall_award, action_date, action_date_fiscal_year, period_of_performance_start_date, period_of_performance_current_end_date, awarding_agency_code, awarding_agency_name, awarding_sub_agency_code, awarding_sub_agency_name, awarding_office_code, awarding_office_name, funding_agency_code, funding_agency_name, funding_sub_agency_code, funding_sub_agency_name, funding_office_code, funding_office_name, treasury_accounts_funding_this_award, federal_accounts_funding_this_award, object_classes_funding_this_award, program_activities_funding_this_award, recipient_uei, recipient_duns, recipient_name, recipient_name_raw, recipient_parent_uei, recipient_parent_duns, recipient_parent_name, recipient_parent_name_raw, recipient_country_code, recipient_country_name, recipient_address_line_1, recipient_address_line_2, recipient_city_code, recipient_city_name, prime_award_transaction_recipient_county_fips_code, recipient_county_name, prime_award_transaction_recipient_state_fips_code, recipient_state_code, recipient_state_name, recipient_zip_code, recipient_zip_last_4_code, prime_award_transaction_recipient_cd_original, prime_award_transaction_recipient_cd_current, recipient_foreign_city_name, recipient_foreign_province_name, recipient_foreign_postal_code, primary_place_of_performance_scope, primary_place_of_performance_country_code, primary_place_of_performance_country_name, primary_place_of_performance_code, primary_place_of_performance_city_name, prime_award_transaction_place_of_performance_county_fips_code, primary_place_of_performance_county_name, prime_award_transaction_place_of_performance_state_fips_code, primary_place_of_performance_state_name, primary_place_of_performance_zip_4, prime_award_transaction_place_of_performance_cd_original, prime_award_transaction_place_of_performance_cd_current, primary_place_of_performance_foreign_location, cfda_number, cfda_title, funding_opportunity_number, funding_opportunity_goals_text, assistance_type_code, assistance_type_description, transaction_description, prime_award_base_transaction_description, business_funds_indicator_code, business_funds_indicator_description, business_types_code, business_types_description, correction_delete_indicator_code, correction_delete_indicator_description, action_type_code, action_type_description, record_type_code, record_type_description, highly_compensated_officer_1_name, ...]
# Index: []
